# %%
from gensim.models import KeyedVectors
import pandas as pd
from collections import Counter
import nltk
import re
import requests

# %%
metadata_table_long = pd.read_json("../data/metadata_table_long.json")
metadata_table_long.head(5)
# Out:
#               Author                                         Full title  \
# 0  Achrelius, Daniel  Scientiarum magnes recitatus publice anno 1690...
# 1  Acidalius, Valens                 Ad Iordanum Brunum Nolanum, Italum
# 2    Acosta, José de  De natura novi orbis libri duo et De promulgat...
# 3     Adam, Melchior  Vitae Germanorum medicorum, qui saeculo superi...
# 4    Addison, Joseph  Ad insignissimum virum dominum Thomam Burnettu...
#
#                                                   In  Year              Place  \
# 0                                               None  1690            [Turku]
# 1  Poematum Iani Lernutii, Iani Gulielmi, Valenti...  1603  Liegnitz, Wrocław
# 2                                               None  1589          Salamanca
# 3                                               None  1620         Heidelberg
# 4  Examen poeticum duplex, sive, Musarum anglican...  1698             London
#
#        Publisher/Printer           Era      Form/Genre  \
# 0                   Wall  17th century         Oration
# 1          Albert, David  17th century  Panegyric poem
# 2       Guillelum Foquel  16th century       Monograph
# 3           Rosa, Geyder  17th century       Biography
# 4  Richard Wellington I.  17th century  Panegyric poem
#
#                                   Discipline/Content  \
# 0  Mathematics, Astronomy/Astrology/Cosmography, ...
# 1                    Astronomy/Astrology/Cosmography
# 2  Astronomy/Astrology/Cosmography, Geography/Car...
# 3                                           Medicine
# 4                         Meteorology/Earth sciences
#
#                                             Original  ...       ids      id  \
# 0                   Scientiarum magnes(Google Books)  ...  [705665]  705665
# 1  Ad Iordanum Brunum (1603)(CAMENA)Ad Iordanum B...  ...  [801745]  801745
# 2  De natura novi orbis(Biodiversity Heritage Lib...  ...  [713323]  713323
# 3  Vitae Germanorum medicorum(MDZ)Alternative lin...  ...  [693148]  693148
# 4  Ad Burnettum sacrae theoriae telluris auctorem...  ...  [769230]  769230
#
#   date_min date_max                                           filename  \
# 0   1690.0   1690.0  Achrelius,_Daniel_-_Scientiarum_magnes__Turku_...
# 1   1603.0   1603.0  Janus_Lernutius_et_al__-_Poemata__Liegnitz_160...
# 2   1589.0   1589.0  Acosta,_José_de_-_De_natura_novi_orbis__Salama...
# 3   1620.0   1620.0  Adam,_Melchior_-_Vitae_Germanorum_medicorum__H...
# 4   1698.0   1698.0        Examen_poeticum_duplex__London_1698_pdf.txt
#
#   file_year sents_n words_n  \
# 0    1690.0     518    6685
# 1    1603.0    6137   66744
# 2    1589.0    9040  135979
# 3    1620.0   16258  153868
# 4    1698.0    3297   38011
#
#                                     disciplines_list   science_class
# 0  [Mathematics, Astronomy/Astrology/Cosmography,...         mixture
# 1                  [Astronomy/Astrology/Cosmography]  exact_sciences
# 2  [Astronomy/Astrology/Cosmography, Geography/Ca...  exact_sciences
# 3                                         [Medicine]   life_sciences
# 4                       [Meteorology/Earth sciences]  exact_sciences
#
# [5 rows x 30 columns]

# %%
lasla = KeyedVectors.load_word2vec_format("../data/large_data/allLASLA-lemmi-fast-100-SKIP-win5-min5.vec")
lasla.most_similar("seminarium")
# Out:
# [('carnarium', 0.8714821934700012),
#  ('sudarium', 0.8584282398223877),
#  ('uinarius', 0.8317396640777588),
#  ('torcularium', 0.8269299864768982),
#  ('armarium', 0.8191075325012207),
#  ('milliarium', 0.8161847591400146),
#  ('mortarium', 0.8139163255691528),
#  ('asinarius', 0.7973707318305969),
#  ('pomarium', 0.7952086329460144),
#  ('olearius', 0.7895564436912537)]

# %%
lasla.most_similar("semen", topn=20)
# Out:
# [('sementis', 0.7769805788993835),
#  ('germen', 0.65008145570755),
#  ('legumen', 0.6492693424224854),
#  ('materies', 0.62647545337677),
#  ('sulcus', 0.6210277080535889),
#  ('stercoro', 0.6130126118659973),
#  ('genitalis', 0.6120802760124207),
#  ('sumen', 0.6056757569313049),
#  ('animans', 0.5975176095962524),
#  ('elementa', 0.5954310297966003),
#  ('seges', 0.5945314764976501),
#  ('primordium', 0.5920283198356628),
#  ('bipalium', 0.589260995388031),
#  ('omnigenus', 0.5877910256385803),
#  ('ablaqueo', 0.5792651772499084),
#  ('renascor', 0.573520839214325),
#  ('enascor', 0.5693485736846924),
#  ('abdomen', 0.5686165690422058),
#  ('priuus', 0.5666219592094421),
#  ('augmen', 0.5655484795570374)]

# %%
lasla.index_to_key[:10]
# Out:
# ['</s>', 'sum', 'et', 'qui', 'in', 'non', 'hic', 'is', 'ut', 'ego']

# %%
operamaiora = KeyedVectors.load_word2vec_format("../data/large_data/opera-maiora-lemmas_skip_100.vec")
operamaiora.most_similar("anima")
# Out:
# [('intellectiuus', 0.7068129181861877),
#  ('separo', 0.7005686163902283),
#  ('sensifico', 0.6973943114280701),
#  ('sensitiuus', 0.6771702766418457),
#  ('corpus', 0.663750171661377),
#  ('uegetabilis', 0.6309762597084045),
#  ('unio', 0.6247175931930542),
#  ('rationalis', 0.623648464679718),
#  ('uegetatiuus', 0.618419885635376),
#  ('corporeus', 0.60992830991745)]

# %%
operamaiora.most_similar("semen")
# Out:
# [('formatiuus', 0.7347741723060608),
#  ('decidocaedo', 0.7292525768280029),
#  ('sementis', 0.7260836362838745),
#  ('decisio', 0.7189536094665527),
#  ('proauus', 0.708860456943512),
#  ('menstruus', 0.7087300419807434),
#  ('fetus', 0.7033669948577881),
#  ('incubus', 0.6823227405548096),
#  ('seminalis', 0.6802768111228943),
#  ('spumosus', 0.6695919036865234)]

# %%
operamaiora_vocab = operamaiora.index_to_key
len(operamaiora_vocab)
# Out:
# 6724

# %%
lasla_vocab = lasla.index_to_key
len(lasla_vocab)
# Out:
# 11327

# %%
vocab_overlap = list(set(lasla_vocab) & set(operamaiora_vocab))
len(vocab_overlap)
# Out:
# 3950

# %%
def get_filtered_counts_by_ids(ids):
    vocab_counter = Counter() # initiate an empty counter of words - we will feed it iterarively on the go by all words we meet
    for id in ids:
        # based on the ID, open the file containing the lemmatized sentences and load its content as a list of lists
        with open("../data/large_data/sents_lemmata/{}.txt".format(str(id)), "r") as f:
            sents_lemmata = [sent.strip().split() for sent in f.readlines()]
        # based on the ID, open the file containing POS tags of the sentences and load its content as a list of lists
        # (this object should have the same structure as the previous one, what allows us to do a sort of filtering based on selected POS tags
        with open("../data/large_data/sents_pos/{}.txt".format(str(id)), "r") as f:
            sents_pos = [sent.strip().split() for sent in f.readlines()]
        sents_lemmata_filtered = [] # initiate a new empty list for sentence lemmata filtered by POS tags 
        for n in range(len(sents_lemmata)):
            try:
                pos_indices = [t[0] for t in enumerate(sents_pos[n]) if t[1] in ["PROPN", "NOUN","VERB", "ADJ", "ADV"]]
                sent_filtered = [sents_lemmata[n][i] for i in pos_indices]
                sent_filtered = [re.sub("\W*|\d*", "", t) for t in sent_filtered]
                sent_filtered = [t for t in sent_filtered if len(t)>1]
            except:
                sent_filtered = []
            sents_lemmata_filtered.append(sent_filtered)
        lemmata = [l for s in sents_lemmata_filtered for l in s] # represent the whole work as one continuous list of (filtered) words
        word_counts = dict(nltk.FreqDist(lemmata).most_common()) # count all (filtered) words within the lemmata list
        vocab_counter.update(word_counts) # update the counter by these words
    return vocab_counter

# %%
def get_filtered_counts_by_ids_old(ids):
    vocab_counter = Counter() # initiate an empty counter of words - we will feed it iterarively on the go by all words we meet
    for id in ids:
        # based on the ID, open the file containing the lemmatized sentences and load its content as a list of lists
        with open("../data/large_data/sents_lemmata/{}.txt".format(str(id)), "r") as f:
            sents_lemmata = [sent.strip().split() for sent in f.readlines()]
        # based on the ID, open the file containing POS tags of the sentences and load its content as a list of lists
        # (this object should have the same structure as the previous one, what allows us to do a sort of filtering based on selected POS tags
        with open("../data/large_data/sents_pos/{}.txt".format(str(id)), "r") as f:
            sents_pos = [sent.strip().split() for sent in f.readlines()]
        sents_lemmata_filtered = [] # initiate a new empty list for sentence lemmata filtered by POS tags 
        for n in range(len(sents_lemmata)):
            try:
                pos_indices = [t[0] for t in enumerate(sents_pos[n]) if t[1] in ["PROPN", "NOUN","VERB", "ADJ", "ADV"]]
                sent_filtered = [sents_lemmata[n][i] for i in pos_indices]
                sent_filtered = [re.sub("\W*|\d*", "", t) for t in sent_filtered]
                sent_filtered = [t for t in sent_filtered if len(t)>1]
            except:
                sent_filtered = []
            sents_lemmata_filtered.append(sent_filtered)
        lemmata = [l for s in sents_lemmata_filtered for l in s] # represent the whole work as one continuous list of (filtered) words
        word_counts = dict(nltk.FreqDist(lemmata).most_common()) # count all (filtered) words within the lemmata list
        vocab_counter.update(word_counts) # update the counter by these words
    return vocab_counter

# %%
ids = metadata_table_long[metadata_table_long["file_year"].between(1600, 1610)]["id"]
vocab = get_filtered_counts_by_ids(ids)

# %%
vocab
# Out:
# Counter({'etiam': 7217,
#          'tamen': 4452,
#          'quidem': 3338,
#          'sic': 3053,
#          'igitur': 3026,
#          'ita': 2626,
#          'uero': 2264,
#          'autem': 2200,
#          'magis': 2079,
#          'enim': 2032,
#          'quoque': 1861,
#          'nunc': 1796,
#          'ergo': 1784,
#          'scilicet': 1586,
#          'iam': 1456,
#          'deinde': 1418,
#          'itaque': 1405,
#          'tum': 1382,
#          'tam': 1372,
#          'item': 1227,
#          'hinc': 1184,
#          'tantum': 1143,
#          'cur': 1141,
#          'simul': 1077,
#          'satis': 1027,
#          'semper': 1020,
#          'ubi': 999,
#          'inde': 993,
#          'quasi': 963,
#          'tandem': 927,
#          'jam': 925,
#          'at': 904,
#          'adhuc': 890,
#          'vnde': 855,
#          'uelut': 850,
#          'aliquando': 850,
#          'unde': 798,
#          'ideo': 797,
#          'quare': 787,
#          'tunc': 782,
#          'ut': 771,
#          'admodum': 767,
#          'nam': 760,
#          'postea': 756,
#          'praesertim': 749,
#          'supra': 744,
#          'uidelicet': 710,
#          'prius': 653,
#          'interdum': 648,
#          'statim': 645,
#          'quomodo': 641,
#          'ibidem': 611,
#          'multum': 579,
#          'praeterea': 577,
#          'vbi': 574,
#          'qvi': 568,
#          'paruus': 548,
#          'parum': 547,
#          'uix': 542,
#          'denique': 531,
#          'quemadmodum': 530,
#          'tamquam': 530,
#          'qve': 523,
#          'rursus': 514,
#          'multus': 511,
#          'potius': 496,
#          'hic': 488,
#          'olim': 487,
#          'ueluti': 483,
#          'vt': 478,
#          'saepe': 476,
#          'omnino': 468,
#          'saltem': 467,
#          'partim': 464,
#          'numquam': 462,
#          'huiusmodi': 442,
#          'ualde': 441,
#          'quantum': 432,
#          'qvod': 430,
#          'quam': 421,
#          'propterea': 419,
#          'antea': 411,
#          'sicut': 407,
#          'prorsus': 389,
#          'primùm': 381,
#          'diu': 374,
#          'ss': 374,
#          'adeo': 370,
#          'paulò': 366,
#          'similiter': 362,
#          'ualdè': 360,
#          'primum': 358,
#          'vna': 358,
#          'primo': 343,
#          'inuicem': 338,
#          'interim': 327,
#          'aliter': 324,
#          'paulo': 320,
#          'quandoquidem': 319,
#          'bene': 318,
#          'ibi': 318,
#          'solum': 314,
#          'diligenter': 314,
#          'quippe': 311,
#          'hactenus': 310,
#          'nondum': 301,
#          'usque': 296,
#          'facile': 295,
#          'primus': 284,
#          'qui': 280,
#          'porrò': 278,
#          'sursum': 278,
#          'fere': 276,
#          'iterum': 270,
#          'insuper': 268,
#          'calendar': 264,
#          'demum': 261,
#          'istic': 261,
#          'prope': 256,
#          'dumtaxat': 253,
#          'circiter': 252,
#          'alibi': 250,
#          'quodammodo': 249,
#          'mox': 247,
#          'deorsum': 246,
#          'nempe': 245,
#          'schenck': 245,
#          'uulgus': 244,
#          'longe': 243,
#          'multo': 243,
#          'hodie': 234,
#          'semel': 233,
#          'nimis': 232,
#          'ample': 229,
#          'quòd': 228,
#          'procul': 227,
#          'paulatim': 224,
#          'huc': 223,
#          'intus': 222,
#          'ter': 218,
#          'bis': 218,
#          'que': 216,
#          'vti': 214,
#          'ne': 206,
#          'neque': 204,
#          'uere': 204,
#          'minus': 203,
#          'passim': 202,
#          'illic': 201,
#          'magne': 201,
#          'planè': 201,
#          'foris': 200,
#          'pręsertim': 200,
#          'recte': 196,
#          'totidem': 195,
#          'deinceps': 194,
#          'infra': 191,
#          'nonnunquam': 191,
#          'tanto': 189,
#          'praecipue': 186,
#          'ante': 185,
#          'maximè': 185,
#          'uerum': 184,
#          'duntaxat': 183,
#          'quapropter': 179,
#          'longè': 178,
#          'nimium': 174,
#          'mane': 166,
#          'simpliciter': 165,
#          'plane': 164,
#          'aequaliter': 160,
#          'qvam': 159,
#          'modo': 158,
#          'etenim': 157,
#          'necessariò': 155,
#          'nihilominus': 153,
#          'potissimum': 151,
#          'perinde': 149,
#          'pręter': 149,
#          'porro': 148,
#          'sensim': 147,
#          'tantummodo': 147,
#          'istîc': 145,
#          'plus': 144,
#          'iv': 142,
#          'expression': 141,
#          'ideò': 141,
#          'plerumque': 140,
#          'utrius': 138,
#          'cito': 137,
#          'iii': 134,
#          'nequaquam': 133,
#          'sum': 131,
#          'frustra': 130,
#          'uehementer': 130,
#          'is': 129,
#          'interea': 127,
#          'eiusmodi': 127,
#          'imo': 126,
#          'qvid': 125,
#          'tùm': 124,
#          'male': 123,
#          'inprimis': 123,
#          'plerusque': 123,
#          'nimirum': 122,
#          'fortasse': 122,
#          'post': 122,
#          'aliquantulum': 121,
#          'sane': 121,
#          'nonnihil': 120,
#          'quâ': 118,
#          'ta': 118,
#          'extrinsecus': 118,
#          'umquam': 116,
#          'attamen': 116,
#          'vnquam': 114,
#          'pariter': 113,
#          'aër': 113,
#          'hujusmodi': 113,
#          'eò': 112,
#          'foras': 111,
#          'quandoque': 111,
#          'idem': 110,
#          'postremo': 110,
#          'tarde': 110,
#          'latinè': 110,
#          'quamobrem': 109,
#          'tertius': 109,
#          'suprà': 109,
#          'by': 105,
#          'ultra': 104,
#          'secus': 103,
#          'penitus': 102,
#          'fortassis': 102,
#          'xvi': 102,
#          'forte': 101,
#          'alias': 101,
#          'reuera': 100,
#          'nuper': 99,
#          'xx': 97,
#          'itidem': 97,
#          'auic': 97,
#          'facilis': 95,
#          'siquidem': 95,
#          'utrin': 94,
#          'xxi': 94,
#          'seorsim': 94,
#          'eleganter': 94,
#          'propemodum': 93,
#          'quanto': 93,
#          'suâ': 92,
#          'solummodo': 92,
#          'non': 91,
#          'multò': 91,
#          'difficulter': 91,
#          'uersus': 91,
#          'alius': 90,
#          'utpote': 90,
#          'mediocriter': 90,
#          'contra': 89,
#          'tantùm': 88,
#          'secundo': 88,
#          'cottidie': 88,
#          'ubique': 87,
#          'feliciter': 87,
#          'quod': 87,
#          'plurimùm': 87,
#          'pręcipue': 87,
#          'communiter': 86,
#          'semidiameter': 85,
#          'denuò': 85,
#          'melius': 85,
#          'perpetuo': 84,
#          'xviii': 84,
#          'nusquam': 84,
#          'haut': 83,
#          'mutuò': 83,
#          'propriè': 83,
#          'quin': 82,
#          'subinde': 82,
#          'idcirco': 81,
#          'breuiter': 81,
#          'eo': 79,
#          'aliunde': 79,
#          'uulgo': 79,
#          'imò': 77,
#          'noctu': 77,
#          'proprie': 77,
#          'frequenter': 76,
#          'uicissim': 75,
#          'prior': 75,
#          'vs': 75,
#          'certe': 74,
#          'quinetiam': 73,
#          'euidenter': 73,
#          'interdiu': 73,
#          'sigillatim': 73,
#          'anteà': 73,
#          'qvidem': 72,
#          'proinde': 72,
#          'mutuo': 72,
#          'alicubi': 71,
#          'pene': 71,
#          'quoties': 70,
#          'xxiii': 70,
#          'nouembris': 70,
#          'hucusque': 70,
#          'postridie': 70,
#          'fortiter': 69,
#          'scrupulis': 69,
#          'quisque': 69,
#          'cplendar': 69,
#          'vicissim': 68,
#          'ceu': 68,
#          'obiter': 68,
#          'forsitan': 67,
#          'postmodum': 67,
#          'facilè': 67,
#          'quando': 67,
#          'quot': 67,
#          'ejusmodi': 67,
#          'leuiter': 65,
#          'cùm': 64,
#          'mo': 64,
#          'nedum': 64,
#          'equidem': 64,
#          'naturaliter': 64,
#          'raro': 64,
#          'mart': 64,
#          'undique': 63,
#          'forsan': 63,
#          'firme': 63,
#          'aliquoties': 63,
#          'experientiâ': 63,
#          'secundus': 62,
#          'ia': 62,
#          'mutuus': 62,
#          'cuiusmodi': 62,
#          'quarto': 60,
#          'qvaestio': 60,
#          'super': 59,
#          'ca': 59,
#          'sursùms': 59,
#          'toties': 58,
#          'eâdem': 58,
#          'una': 58,
#          'celeriter': 58,
#          'late': 57,
#          'libenter': 57,
#          'april': 57,
#          'solus': 56,
#          'coniunctim': 56,
#          'ix': 54,
#          'quotquot': 54,
#          'illâ': 53,
#          'domi': 53,
#          'sensibiliter': 53,
#          'denuo': 53,
#          'accuratè': 53,
#          'breui': 52,
#          'certòs': 52,
#          'paululum': 52,
#          'postremò': 52,
#          'modus': 52,
#          'febr': 52,
#          'eclipsis': 52,
#          'qvos': 51,
#          'apprimè': 51,
#          'fi': 51,
#          'subito': 50,
#          'intemperie': 50,
#          'modice': 50,
#          'retro': 49,
#          'sufficienter': 49,
#          'potissimùm': 49,
#          'centra': 49,
#          'exacte': 49,
#          'intro': 49,
#          'meâ': 48,
#          'perpendiculariter': 48,
#          'aprilis': 48,
#          'partiliter': 48,
#          'repente': 47,
#          'perperam': 47,
#          'priuatim': 47,
#          'commode': 47,
#          'clare': 46,
#          'temere': 46,
#          'uel': 46,
#          'accurate': 46,
#          'graece': 46,
#          'pridem': 45,
#          'namque': 45,
#          'continuo': 45,
#          'uerus': 45,
#          'sa': 45,
#          'ibid': 45,
#          'imprimis': 45,
#          'xxxi': 44,
#          'vltra': 44,
#          'alternatim': 44,
#          'praecise': 44,
#          'cal': 44,
#          'secundę': 44,
#          'ceruix': 44,
#          'quantò': 44,
#          'dehinc': 43,
#          'die': 43,
#          'proximè': 43,
#          'uti': 43,
#          'quantumuis': 43,
#          'diameter': 43,
#          'illuc': 42,
#          'ra': 42,
#          'aliquantulus': 42,
#          'ferme': 42,
#          'co': 42,
#          'generaliter': 42,
#          'gratiâ': 42,
#          'generatim': 42,
#          'utrimque': 42,
#          'alte': 41,
#          'rum': 41,
#          'constanter': 41,
#          'scrupulum': 41,
#          'pars': 41,
#          'perfectè': 41,
#          'sept': 41,
#          'necessario': 41,
#          'cutim': 41,
#          'xv': 40,
#          'principaliter': 40,
#          'inaequaliter': 40,
#          'diutiùs': 40,
#          'extra': 40,
#          'illico': 40,
#          'interp': 40,
#          'quàm': 39,
#          'xxix': 39,
#          'quo': 39,
#          'adeò': 39,
#          'citius': 39,
#          'qvaest': 39,
#          'bonus': 38,
#          'sero': 38,
#          'infeliciter': 38,
#          'aeque': 38,
#          'sed': 38,
#          'nullatenus': 38,
#          'insensibiliter': 38,
#          'saepenumerò': 38,
#          'copiose': 38,
#          'dam': 38,
#          'retrorsus': 38,
#          'grauiter': 37,
#          'proculdubio': 37,
#          'manifeste': 37,
#          'speciatim': 36,
#          'nisi': 35,
#          'sec': 35,
#          'quorsum': 35,
#          'ns': 35,
#          'circulariter': 35,
#          'aliâs': 35,
#          'peculiariter': 35,
#          'cujusmodi': 35,
#          'hisce': 34,
#          'ferè': 34,
#          'insigniter': 34,
#          'magnus': 34,
#          'confertim': 34,
#          'tertio': 34,
#          'anteriùs': 34,
#          'utiliter': 34,
#          'utrum': 33,
#          'omnis': 33,
#          'quatenus': 33,
#          'demùm': 33,
#          'infere': 33,
#          'quater': 33,
#          'plerun': 33,
#          'sphenoidem': 33,
#          'prorsùs': 33,
#          'separatim': 32,
#          'tis': 32,
#          'antiquitus': 32,
#          'seorsis': 32,
#          'eapropter': 32,
#          'xxvii': 31,
#          'freqventer': 31,
#          'quis': 31,
#          'rarus': 31,
#          'aliquandiu': 31,
#          'intrinsecus': 31,
#          'uenter': 31,
#          'kl': 31,
#          'xl': 30,
#          'conuenienter': 30,
#          'tutò': 30,
#          'quoad': 30,
#          'venter': 30,
#          'quarè': 30,
#          'imp': 30,
#          'leniter': 29,
#          'mus': 29,
#          'scheat': 29,
#          'luculenter': 29,
#          'proportionaliter': 29,
#          'superius': 29,
#          'necesse': 29,
#          'quartò': 29,
#          'quędam': 29,
#          'perfecte': 29,
#          'nonnumquam': 29,
#          'gregatim': 29,
#          'immo': 28,
#          'vndet': 28,
#          'tantundes': 28,
#          'propriès': 28,
#          'confestim': 28,
#          'aegre': 28,
#          'tia': 28,
#          'ma': 28,
#          'posterus': 28,
#          'quum': 28,
#          'qvo': 27,
#          'utinam': 27,
#          'malus': 27,
#          'natu': 27,
#          'certus': 27,
#          'quondam': 27,
#          'uiolenter': 27,
#          'ge': 27,
#          'aliquomodo': 27,
#          'plene': 27,
#          'consequenter': 27,
#          'latine': 27,
#          'recenter': 27,
#          'alioqui': 27,
#          'obscure': 27,
#          'caeterum': 27,
#          'atque': 27,
#          'transversim': 27,
#          'dudum': 26,
#          'ultro': 26,
#          'dein': 26,
#          'us': 26,
#          'xxxviii': 26,
#          'nullibi': 26,
#          'ci': 26,
#          'lam': 26,
#          'plusquam': 26,
#          'ee': 26,
#          'inibi': 26,
#          'quinta': 26,
#          'proxime': 26,
#          'intùs': 26,
#          'gr': 26,
#          'qvasi': 26,
#          'sat': 25,
#          'probe': 25,
#          'quodque': 25,
#          'efficaciter': 25,
#          'ce': 25,
#          'praetereà': 25,
#          'posthac': 24,
#          'tot': 24,
#          'molliter': 24,
#          'ultimus': 24,
#          'protinus': 24,
#          'ab': 24,
#          'varie': 24,
#          'utut': 24,
#          'xxiiii': 24,
#          'ipse': 24,
#          'siue': 24,
#          'fideliter': 24,
#          'nunquam': 24,
#          'quartus': 24,
#          'pri': 24,
#          'haudquaquam': 24,
#          'quintus': 24,
#          'si': 24,
#          'quatenùs': 24,
#          'connexis': 24,
#          'quomodò': 24,
#          'justus': 24,
#          'supernâ': 24,
#          'unicè': 23,
#          'sedulò': 23,
#          'uarius': 23,
#          'tantopere': 23,
#          'exactius': 23,
#          'optimè': 23,
#          'saepenumero': 23,
#          'introrsus': 23,
#          'large': 23,
#          'intra': 23,
#          'quamprimum': 23,
#          'oblique': 23,
#          'quarta': 23,
#          'insimul': 23,
#          'breviter': 23,
#          'novilunia': 23,
#          'qvia': 22,
#          'um': 22,
#          'parumper': 22,
#          'paullò': 22,
#          'audacter': 22,
#          'uulgariter': 22,
#          'aliquanto': 22,
#          'minutim': 22,
#          'xxii': 22,
#          'libere': 22,
#          'fg': 22,
#          'antere': 22,
#          'quan': 22,
#          'circumcirca': 22,
#          'grad': 22,
#          'palam': 21,
#          'brevi': 21,
#          'saepè': 21,
#          'quòad': 21,
#          'copiosè': 21,
#          'vmquam': 21,
#          'quamdiu': 21,
#          'scr': 21,
#          'quibuscun': 21,
#          'rare': 21,
#          'na': 21,
#          'majore': 20,
#          'mn': 20,
#          'dc': 20,
#          'directe': 20,
#          'aperte': 20,
#          'hh': 20,
#          'immediatè': 20,
#          'ed': 20,
#          'tuto': 20,
#          'particulatim': 20,
#          'ęqualiter': 20,
#          'om': 20,
#          'vberrimè': 20,
#          'dupliciter': 20,
#          'infrà': 20,
#          'tantò': 20,
#          'perindeac': 20,
#          'dense': 20,
#          'sil': 20,
#          'justo': 20,
#          'quad': 20,
#          'ceterum': 20,
#          'heic': 19,
#          'ast': 19,
#          'certo': 19,
#          'haud': 19,
#          'affatim': 19,
#          'quomodocun': 19,
#          'quadrante': 19,
#          'summatim': 19,
#          'vno': 19,
#          'ar': 19,
#          'in': 19,
#          'postrema': 19,
#          'abunde': 19,
#          'superior': 19,
#          'utrun': 19,
#          'conuexa': 19,
#          'sensis': 19,
#          'expresse': 19,
#          'index': 19,
#          'paullulum': 19,
#          'fortassè': 19,
#          'prętereà': 19,
#          'cl': 19,
#          'internâ': 19,
#          'aldr': 19,
#          'perpetim': 18,
#          'qvae': 18,
#          'et': 18,
#          'leuis': 18,
#          'uerius': 18,
#          'assidue': 18,
#          'vtpote': 18,
#          'exactè': 18,
#          'ie': 18,
#          'unà': 18,
#          'expressè': 18,
#          'ult': 18,
#          'ol': 18,
#          'liberaliter': 18,
#          'ti': 18,
#          'profecto': 18,
#          'celerius': 18,
#          'mum': 18,
#          'mirabiliter': 18,
#          'perquam': 18,
#          'ὡς': 18,
#          'xa': 18,
#          'octobr': 18,
#          'idus': 18,
#          'antehac': 17,
#          'xxxix': 17,
#          'no': 17,
#          'sam': 17,
#          'diligentissimè': 17,
#          'continue': 17,
#          'syncope': 17,
#          'exterior': 17,
#          'nemine': 17,
#          'naturę': 17,
#          'magnopere': 17,
#          'sparsim': 17,
#          'indifferenter': 17,
#          'lxii': 17,
#          'lvii': 17,
#          'septemb': 17,
#          'conjunctim': 17,
#          'inqvam': 16,
#          'qvin': 16,
#          'qvoties': 16,
#          'immerito': 16,
#          'summe': 16,
#          'utcun': 16,
#          'econtra': 16,
#          'aut': 16,
#          'rarò': 16,
#          'se': 16,
#          'aequè': 16,
#          'longus': 16,
#          'bc': 16,
#          'dies': 16,
#          'nemo': 16,
#          'naius': 16,
#          'ad': 16,
#          'quinquies': 16,
#          'circa': 16,
#          'ae': 16,
#          'citissimè': 16,
#          'aegrè': 16,
#          'ualenter': 16,
#          'recens': 16,
#          'paullatim': 16,
#          'an': 16,
#          'dexter': 16,
#          'continenter': 16,
#          'kk': 16,
#          'pridie': 16,
#          'diutissime': 16,
#          'unus': 16,
#          'distantiâ': 16,
#          'regulariter': 16,
#          'xxiv': 16,
#          'seu': 15,
#          'nec': 15,
#          'ni': 15,
#          'publicus': 15,
#          'clam': 15,
#          'xxxvi': 15,
#          'illicus': 15,
#          'amplus': 15,
#          'eiuscemodi': 15,
#          'adamussim': 15,
#          'diuersimodè': 15,
#          'ulteriùs': 15,
#          'er': 15,
#          'uerò': 15,
#          'anterius': 15,
#          'sententiâ': 15,
#          'af': 15,
#          'summè': 15,
#          'negligenter': 15,
#          'sertim': 15,
#          'li': 15,
#          'tantus': 15,
#          'eb': 15,
#          'novemb': 15,
#          'lx': 15,
#          'turca': 15,
#          'transversis': 15,
#          'gratis': 15,
#          'ein': 15,
#          'unice': 14,
#          'illinc': 14,
#          'cum': 14,
#          'desuper': 14,
#          'tim': 14,
#          'acriter': 14,
#          'novemeris': 14,
#          'quadrans': 14,
#          'probabiliter': 14,
#          'bifariam': 14,
#          'pedetentim': 14,
#          'multoties': 14,
#          'xxvi': 14,
#          'ua': 14,
#          'abhinc': 14,
#          'proculdubiò': 14,
#          'crebro': 14,
#          'idcircò': 14,
#          'adcò': 14,
#          'efficacius': 14,
#          'pe': 14,
#          'ras': 14,
#          'absolute': 14,
#          'immediate': 14,
#          'mae': 14,
#          'nou': 14,
#          'humi': 14,
#          'ec': 14,
#          'firmiter': 14,
#          'artificiose': 14,
#          'minimè': 14,
#          'decussatim': 14,
#          'imper': 14,
#          'indidem': 14,
#          'aequabiliter': 14,
#          'exiguâ': 14,
#          'octobris': 14,
#          'paucâ': 14,
#          'lug': 14,
#          'tych': 14,
#          'nouissime': 14,
#          'illustriss': 14,
#          'qvibusdam': 14,
#          'qvodammodo': 14,
#          'misere': 13,
#          'qvâ': 13,
#          'turpiter': 13,
#          'annus': 13,
#          'numerus': 13,
#          'subter': 13,
#          'ille': 13,
#          'ubicun': 13,
#          'uirides': 13,
#          'eg': 13,
#          'latiùs': 13,
#          'sublimis': 13,
#          'dico': 13,
#          'ga': 13,
#          'orbiculariter': 13,
#          'qvinta': 13,
#          'minutatim': 13,
#          'be': 13,
#          'quartum': 13,
#          'pręterea': 13,
#          'qu': 13,
#          'nonn': 13,
#          'anterus': 13,
#          'quartę': 13,
#          'specialiter': 13,
#          'uerumetiam': 13,
#          'fb': 13,
#          'recèns': 13,
#          'usquam': 12,
#          'cù': 12,
#          'eiusdem': 12,
#          'xxxii': 12,
#          'obuiam': 12,
#          'quibo': 12,
#          'subtiliter': 12,
#          'quoquam': 12,
#          'quamplurimis': 12,
#          'necdum': 12,
#          'tantisper': 12,
#          'am': 12,
#          'locus': 12,
#          'absolutè': 12,
#          'prudenter': 12,
#          'nov': 12,
#          'nter': 12,
#          'uter': 12,
#          'singulatim': 12,
#          'facio': 12,
#          'tan': 12,
#          'exterius': 12,
#          'sępius': 12,
#          'supernus': 12,
#          'penite': 12,
#          'cir': 12,
#          'inferus': 12,
#          'praestantius': 12,
#          'ob': 12,
#          'abundanter': 12,
#          'ualidius': 12,
#          'extrorsum': 12,
#          'sextus': 12,
#          'anguste': 12,
#          'septiens': 12,
#          'connexa': 12,
#          'fgh': 12,
#          'aliqvot': 12,
#          'infrequenter': 12,
#          'uerumtamen': 12,
#          'liter': 12,
#          'aliquâ': 12,
#          'substantiâ': 12,
#          'ejusmodus': 12,
#          'cvm': 12,
#          'maii': 12,
#          'ilico': 12,
#          'nisan': 12,
#          'temp': 12,
#          'lugd': 12,
#          'raptim': 11,
#          'quidni': 11,
#          'paene': 11,
#          'fors': 11,
#          'sedulo': 11,
#          'te': 11,
#          'paullisper': 11,
#          'latus': 11,
#          'quî': 11,
#          'dure': 11,
#          'iis': 11,
#          'rursum': 11,
#          'inconuenienter': 11,
#          'pertinaciter': 11,
#          'rectissimè': 11,
#          'nouiter': 11,
#          'rationabiliter': 11,
#          'utique': 11,
#          'affabrè': 11,
#          'ex': 11,
#          'habeo': 11,
#          'nos': 11,
#          'caput': 11,
#          'decemb': 11,
#          'bh': 11,
#          'commodè': 11,
#          'graue': 11,
#          'celerrime': 11,
#          'tius': 11,
#          'tute': 11,
#          'interior': 11,
#          'men': 11,
#          'crassus': 11,
#          'gra': 11,
#          'fo': 11,
#          'uideo': 11,
#          'profunde': 11,
#          'summopere': 11,
#          'paucus': 11,
#          'propinque': 11,
#          'diutissimè': 11,
#          'on': 11,
#          'quocirca': 11,
#          'promptissimè': 11,
#          'utar': 11,
#          'fig': 11,
#          'quodpiam': 11,
#          'suus': 11,
#          'pr': 11,
#          'aliquamdiu': 11,
#          'xlviii': 11,
#          'octob': 11,
#          'abundantiâ': 11,
#          'eim': 11,
#          'eiusd': 11,
#          'lingvae': 10,
#          'junctim': 10,
#          'cunque': 10,
#          'mollis': 10,
#          'cras': 10,
#          'saepius': 10,
#          'quique': 10,
#          'hodiè': 10,
#          'nonne': 10,
#          'ultere': 10,
#          'pure': 10,
#          'scrupulosè': 10,
#          'apparenter': 10,
#          'apprime': 10,
#          'transuersis': 10,
#          'aliquatenus': 10,
#          'lm': 10,
#          'furtim': 10,
#          'multifariam': 10,
#          'cuiuis': 10,
#          'fa': 10,
#          'uerissimè': 10,
#          'tamdiu': 10,
#          'dato': 10,
#          'vnus': 10,
#          'accuratissimè': 10,
#          'uetus': 10,
#          'unt': 10,
#          'plu': 10,
#          'nan': 10,
#          'fusius': 10,
#          'aliquantulùm': 10,
#          'quamprimùm': 10,
#          'perpetuò': 10,
#          'possum': 10,
#          'uelociter': 10,
#          'multipliciter': 10,
#          'succus': 10,
#          'su': 10,
#          'uim': 10,
#          'leue': 10,
#          ...})

# %%
vocab
# Out:
# Counter({'pars': 10691,
#          'omnis': 8423,
#          'etiam': 7362,
#          'dico': 6585,
#          'habeo': 6412,
#          'facio': 6284,
#          'locus': 5859,
#          'possum': 5602,
#          'suus': 5461,
#          'annus': 5314,
#          'magnus': 5164,
#          'os': 5076,
#          'primus': 4968,
#          'multus': 4882,
#          'uideo': 4663,
#          'motus': 4632,
#          'tamen': 4532,
#          'uerò': 4392,
#          'tempus': 4186,
#          'corpus': 4177,
#          'caput': 4175,
#          'cap': 4012,
#          'dies': 3941,
#          'ratio': 3781,
#          'totus': 3644,
#          'res': 3541,
#          'quidem': 3384,
#          'sol': 3381,
#          'liber': 3373,
#          'paruus': 3272,
#          'medius': 3166,
#          'alter': 3128,
#          'sic': 3087,
#          'natura': 3049,
#          'igitur': 3043,
#          'quàm': 3041,
#          'galenus': 3002,
#          'lib': 2840,
#          'nullus': 2791,
#          'modus': 2767,
#          'terra': 2760,
#          'do': 2714,
#          'ita': 2662,
#          'luna': 2636,
#          'tertius': 2578,
#          'angulus': 2548,
#          'noster': 2532,
#          'oculus': 2522,
#          'quintus': 2412,
#          'color': 2360,
#          'uero': 2302,
#          'aqua': 2250,
#          'secundus': 2244,
#          'autem': 2237,
#          'cor': 2196,
#          'genus': 2176,
#          'uis': 2152,
#          'cùm': 2150,
#          'medicus': 2144,
#          'nascor': 2118,
#          'nomen': 2117,
#          'magis': 2113,
#          'latus': 2076,
#          'enim': 2064,
#          'homo': 2045,
#          'similis': 2014,
#          'sanguis': 2008,
#          'causa': 2007,
#          'que': 1948,
#          'fero': 1940,
#          'stella': 1935,
#          'signum': 1914,
#          'solus': 1902,
#          'quoque': 1890,
#          'scribo': 1847,
#          'uolo': 1814,
#          'nunc': 1811,
#          'ergo': 1799,
#          'google': 1779,
#          'cometa': 1763,
#          'animal': 1747,
#          'musculus': 1703,
#          'in': 1699,
#          'semen': 1669,
#          'qui': 1661,
#          'opus': 1645,
#          'singulus': 1642,
#          'longitudo': 1634,
#          'quòd': 1631,
#          'numerus': 1620,
#          'distantia': 1617,
#          'scilicet': 1612,
#          'figura': 1580,
#          'circulus': 1579,
#          'grad': 1567,
#          'iam': 1555,
#          'gradus': 1554,
#          'fio': 1544,
#          'reliquus': 1534,
#          'proprius': 1534,
#          'nihil': 1508,
#          'uerus': 1500,
#          'spiritus': 1496,
#          'longus': 1491,
#          'uoco': 1490,
#          'licet': 1487,
#          'digitized': 1482,
#          'domus': 1477,
#          'arteria': 1458,
#          'sinus': 1446,
#          'deinde': 1437,
#          'tum': 1412,
#          'itaque': 1410,
#          'appello': 1408,
#          'superior': 1407,
#          'tam': 1400,
#          'pes': 1392,
#          'unus': 1391,
#          'appareo': 1388,
#          'moueo': 1376,
#          'adeò': 1374,
#          'linea': 1373,
#          'latitudo': 1367,
#          'sequor': 1366,
#          'ars': 1357,
#          'lapis': 1357,
#          'dominus': 1350,
#          'forma': 1344,
#          'meus': 1330,
#          'manus': 1328,
#          'neruus': 1327,
#          'arbor': 1317,
#          'facultas': 1316,
#          'finis': 1309,
#          'fructus': 1302,
#          'hora': 1296,
#          'calidus': 1277,
#          'cerebrum': 1271,
#          'refero': 1266,
#          'inquam': 1266,
#          'quartus': 1261,
#          'caro': 1252,
#          'inuenio': 1236,
#          'item': 1235,
#          'principium': 1233,
#          'significo': 1225,
#          'centrum': 1222,
#          'uita': 1215,
#          'contineo': 1201,
#          'hinc': 1199,
#          'frigidus': 1199,
#          'vsus': 1191,
#          'radix': 1189,
#          'debeo': 1184,
#          'radius': 1180,
#          'ferè': 1179,
#          'summus': 1178,
#          'tantum': 1170,
#          'sum': 1161,
#          'cur': 1159,
#          'communis': 1157,
#          'punctum': 1157,
#          'substantia': 1156,
#          'soleo': 1153,
#          'regio': 1151,
#          'pono': 1142,
#          'sensus': 1138,
#          'tuus': 1131,
#          'constituo': 1122,
#          'uir': 1116,
#          'magnitudo': 1114,
#          'bonus': 1110,
#          'mensis': 1107,
#          'rectus': 1100,
#          'verò': 1099,
#          'differentia': 1098,
#          'prior': 1094,
#          'simul': 1092,
#          'usus': 1087,
#          'species': 1085,
#          'min': 1084,
#          'certus': 1078,
#          'materia': 1077,
#          'lux': 1071,
#          'inferus': 1071,
#          'semper': 1058,
#          'aequalis': 1046,
#          'satis': 1043,
#          'uena': 1039,
#          'calor': 1032,
#          'naturalis': 1032,
#          'dolor': 1023,
#          'ubi': 1021,
#          'orbis': 1017,
#          'exsisto': 1017,
#          'ibid': 1011,
#          'inde': 1008,
#          'folium': 1006,
#          'digitus': 1000,
#          'addo': 999,
#          'uenio': 998,
#          'historia': 997,
#          'duco': 996,
#          'jam': 995,
#          'planeta': 995,
#          'quasi': 989,
#          'edo': 988,
#          'ostendo': 988,
#          'ut': 984,
#          'ago': 980,
#          'albus': 976,
#          'cibus': 976,
#          'crassus': 970,
#          'tandem': 955,
#          'dexter': 952,
#          'polus': 949,
#          'arcus': 947,
#          'puto': 944,
#          'morbus': 932,
#          'cauda': 931,
#          'coelum': 924,
#          'at': 922,
#          'uetus': 922,
#          'consto': 915,
#          'tabula': 908,
#          'adhuc': 905,
#          'uarius': 899,
#          'ascendo': 886,
#          'niger': 885,
#          'aliquando': 883,
#          'instar': 881,
#          'uelut': 877,
#          'christus': 875,
#          'durus': 873,
#          'dens': 871,
#          'mons': 870,
#          'contingo': 870,
#          'deus': 869,
#          'vnde': 869,
#          'humor': 864,
#          'situs': 858,
#          'mart': 858,
#          'ordo': 854,
#          'animus': 839,
#          'initium': 837,
#          'nouus': 827,
#          'aer': 824,
#          'opinio': 823,
#          'sinister': 822,
#          'uirtus': 821,
#          'mars': 814,
#          'caussa': 813,
#          'posterus': 808,
#          'actio': 807,
#          'unde': 802,
#          'ideo': 802,
#          'ferrum': 800,
#          'uerbum': 798,
#          'tunc': 798,
#          'ossis': 797,
#          'admodum': 794,
#          'quare': 789,
#          'supra': 787,
#          'uia': 784,
#          'vena': 779,
#          'nam': 773,
#          'colligo': 772,
#          'hic': 771,
#          'postea': 768,
#          'curo': 762,
#          'praesertim': 762,
#          'superficies': 753,
#          'terminus': 753,
#          'sextus': 752,
#          'uinum': 747,
#          'conuenio': 741,
#          'altitudo': 741,
#          'iter': 740,
#          'intellego': 737,
#          'planetae': 733,
#          'foetus': 732,
#          'demonstro': 732,
#          'mundus': 729,
#          'prius': 729,
#          'efficio': 727,
#          'duplex': 726,
#          'obseruatio': 725,
#          'uidelicet': 724,
#          'vnus': 722,
#          'planus': 721,
#          'describo': 716,
#          'ignis': 715,
#          'error': 715,
#          'quantitas': 714,
#          'febris': 713,
#          'oppono': 712,
#          'internus': 712,
#          'pateo': 711,
#          'refractio': 708,
#          'paucus': 705,
#          'externus': 705,
#          'exemplum': 703,
#          'sententia': 703,
#          'reddo': 702,
#          'accedo': 700,
#          'mare': 697,
#          'relinquo': 694,
#          'planta': 694,
#          'propono': 694,
#          'mors': 691,
#          'organum': 691,
#          'sentio': 690,
#          'differo': 687,
#          'mos': 685,
#          'sumo': 680,
#          'sole': 680,
#          'reperio': 679,
#          'insula': 679,
#          'par': 677,
#          'foramen': 674,
#          'major': 670,
#          'utor': 667,
#          'simplex': 667,
#          'uentriculus': 667,
#          'diuersus': 666,
#          'rex': 665,
#          'urbs': 664,
#          'septimus': 664,
#          'multum': 659,
#          'magneticus': 658,
#          'doceo': 657,
#          'porrò': 657,
#          'interdum': 657,
#          'statim': 657,
#          'labor': 656,
#          'lingua': 655,
#          'quomodo': 655,
#          'tantùm': 653,
#          'qve': 650,
#          'accipio': 649,
#          'episcopus': 648,
#          'declinatio': 646,
#          'processus': 646,
#          'uas': 645,
#          'ramus': 642,
#          'instrumentum': 642,
#          'medicamentum': 637,
#          'mulier': 633,
#          'ibidem': 631,
#          'facilè': 628,
#          'contrarius': 624,
#          'uterus': 624,
#          'exiguus': 622,
#          'modò': 621,
#          'necessarius': 618,
#          'disto': 614,
#          'qvi': 613,
#          'aristoteles': 613,
#          'cauitas': 611,
#          'uenter': 610,
#          'aio': 608,
#          'traho': 608,
#          'graecus': 607,
#          'integer': 607,
#          'magnes': 607,
#          'medulla': 606,
#          'oportet': 605,
#          'oleum': 603,
#          'humanus': 601,
#          'tenuis': 601,
#          'vt': 601,
#          'potus': 595,
#          'sutura': 593,
#          'praecedo': 592,
#          'capvt': 591,
#          'ad': 589,
#          'recipio': 587,
#          'primum': 586,
#          'pag': 584,
#          'praeterea': 582,
#          'mens': 581,
#          'vbi': 580,
#          'fides': 578,
#          'parum': 577,
#          'libellus': 575,
#          'exhibeo': 575,
#          'proportio': 575,
#          'seco': 573,
#          'siccus': 571,
#          'cognosco': 569,
#          'exprimo': 565,
#          'exterior': 565,
#          'caius': 564,
#          'pulmo': 564,
#          'sectio': 561,
#          'anima': 558,
#          'part': 558,
#          'descendo': 557,
#          'uix': 555,
#          'ueluti': 554,
#          'amplus': 553,
#          'uniuersus': 553,
#          'credo': 552,
#          'hortus': 550,
#          'princeps': 549,
#          'affectus': 549,
#          'generatio': 549,
#          'obtineo': 548,
#          'respondeo': 547,
#          'orior': 546,
#          'confero': 546,
#          'incido': 546,
#          'tamquam': 546,
#          'quaero': 545,
#          'quemadmodum': 545,
#          'nox': 544,
#          'lumen': 543,
#          'scio': 541,
#          'denique': 541,
#          'distinguo': 541,
#          'aph': 540,
#          'latinus': 539,
#          'statuo': 539,
#          'ergò': 537,
#          'existimo': 537,
#          'testis': 535,
#          'cauus': 535,
#          'triangulus': 534,
#          'qualitas': 534,
#          'pectus': 533,
#          'partus': 532,
#          'obseruo': 531,
#          'aspectus': 529,
#          'utrin': 524,
#          'lac': 524,
#          'auctor': 521,
#          'minùs': 521,
#          'rursus': 520,
#          'effectus': 520,
#          'potiùs': 520,
#          'vna': 520,
#          'no': 517,
#          'extremus': 514,
#          'aetas': 513,
#          'nuncupo': 513,
#          'calculus': 512,
#          'directio': 512,
#          'marcus': 510,
#          'altus': 508,
#          'spina': 507,
#          'potius': 506,
#          'alimentum': 506,
#          'gratia': 505,
#          'dignitas': 504,
#          'significator': 504,
#          'conuerto': 503,
#          'longè': 501,
#          'iii': 499,
#          'articulus': 498,
#          'is': 497,
#          'conficio': 497,
#          'olim': 496,
#          'solidus': 496,
#          'acutus': 495,
#          'sedes': 493,
#          'lo': 491,
#          'fol': 490,
#          'maximè': 489,
#          'com': 488,
#          'hippocrates': 487,
#          'ioan': 487,
#          'caeterus': 485,
#          'curatio': 485,
#          'perfectus': 483,
#          'saepe': 482,
#          'nosco': 481,
#          'lex': 481,
#          'malus': 479,
#          'uulgus': 479,
#          'tendo': 479,
#          'patior': 479,
#          'saltem': 478,
#          'minimè': 478,
#          'omnino': 478,
#          'mitto': 477,
#          'partim': 476,
#          'rotundus': 474,
#          'uox': 473,
#          'inclinatio': 473,
#          'piscis': 472,
#          'collum': 471,
#          'excipio': 470,
#          'quam': 470,
#          'maneo': 469,
#          'numquam': 469,
#          'observatio': 469,
#          'uncia': 469,
#          'frons': 466,
#          'filius': 466,
#          'trado': 466,
#          'litera': 466,
#          'primùm': 464,
#          'considero': 464,
#          'capio': 460,
#          'facies': 460,
#          'proximus': 457,
#          'planetarum': 457,
#          'obliquus': 457,
#          'hîc': 455,
#          'remedium': 455,
#          'auris': 453,
#          'indico': 453,
#          'huiusmodi': 450,
#          'ualde': 449,
#          'qvod': 446,
#          'doctrina': 445,
#          'observo': 445,
#          'genero': 444,
#          'diurnus': 444,
#          'ingenium': 443,
#          'qvae': 442,
#          'martis': 442,
#          'momentum': 442,
#          'ligamentum': 442,
#          'odor': 440,
#          'paro': 440,
#          'graeci': 440,
#          'umor': 440,
#          'prodeo': 439,
#          'quantum': 438,
#          'horoscopus': 436,
#          'excrementum': 435,
#          'petrus': 434,
#          'malum': 433,
#          'praesto': 432,
#          'adeo': 431,
#          'varius': 431,
#          'numero': 430,
#          'priùs': 430,
#          'tango': 429,
#          'sapor': 429,
#          'membrana': 429,
#          'dignus': 427,
#          'lignum': 424,
#          'humidus': 424,
#          'morbum': 424,
#          'affero': 423,
#          'cortex': 422,
#          'propterea': 421,
#          'regula': 420,
#          'minuo': 420,
#          'antea': 420,
#          'ss': 420,
#          'aequator': 419,
#          'descriptio': 419,
#          'pater': 418,
#          'conspicio': 418,
#          'explico': 418,
#          'bonum': 417,
#          'impono': 417,
#          'binus': 417,
#          'primo': 417,
#          'amor': 416,
#          'instituo': 416,
#          'sicut': 415,
#          'horizons': 415,
#          'plinius': 415,
#          'puer': 414,
#          'retineo': 414,
#          'minutus': 414,
#          'uentriculum': 413,
#          'specto': 412,
#          'herba': 411,
#          'bilis': 411,
#          'nobilis': 409,
#          'loquor': 408,
#          'sanè': 407,
#          'vitalis': 406,
#          'morba': 406,
#          'fuscus': 406,
#          'dorsum': 406,
#          'particula': 405,
#          'paulò': 405,
#          'plenus': 404,
#          'candidus': 404,
#          'mollis': 403,
#          'meridianus': 403,
#          'succus': 402,
#          'prorsus': 401,
#          'muto': 400,
#          'defero': 400,
#          'queo': 400,
#          'adsum': 399,
#          'tribuo': 399,
#          'unicus': 398,
#          'die': 398,
#          'amicus': 397,
#          'deficio': 397,
#          'planè': 397,
#          'aureus': 396,
#          'careo': 396,
#          'rarus': 395,
#          'occasus': 395,
#          'mirus': 394,
#          'transeo': 394,
#          'globus': 393,
#          'ualdè': 393,
#          'ioannis': 392,
#          'breuis': 390,
#          'latitudi': 390,
#          'cornu': 388,
#          'tunica': 386,
#          'augeo': 385,
#          'diu': 383,
#          'rego': 383,
#          'imago': 382,
#          'tycho': 382,
#          'noto': 381,
#          'fortis': 380,
#          'portio': 380,
#          'extendo': 380,
#          'studium': 378,
#          'incipio': 378,
#          'demonstratio': 378,
#          'nonnullus': 378,
#          'cado': 377,
#          'ultimus': 377,
#          'facilis': 377,
#          'necesse': 377,
#          'supero': 376,
#          'impedio': 376,
#          'gal': 376,
#          'perficio': 375,
#          'ascensio': 375,
#          'cum': 374,
#          'meridies': 374,
#          'memini': 373,
#          'maxilla': 371,
#          'romanus': 369,
#          'similiter': 369,
#          'purgo': 369,
#          'peto': 368,
#          'decimus': 367,
#          'notus': 366,
#          'paulo': 366,
#          'lego': 365,
#          'manifestus': 365,
#          'india': 365,
#          'insum': 364,
#          'honor': 363,
#          'sacer': 363,
#          'mater': 363,
#          'profero': 363,
#          'aurum': 362,
#          'cito': 360,
#          'philosophus': 360,
#          'articulatio': 360,
#          'solum': 358,
#          'difficilis': 358,
#          'tibia': 358,
#          'coniungo': 358,
#          'paulus': 357,
#          'argumentum': 357,
#          'continuus': 357,
#          'non': 356,
#          'ab': 356,
#          'adhibeo': 356,
#          'ingredior': 355,
#          'respiratio': 355,
#          'exeo': 354,
#          'periculum': 353,
#          'lucius': 352,
#          'interior': 352,
#          'medicinus': 351,
#          'pondus': 351,
#          'grauis': 350,
#          'quâ': 350,
#          'sec': 349,
#          'exc': 349,
#          'sto': 348,
#          'occupo': 348,
#          'inuicem': 348,
#          'praebeo': 348,
#          'teneo': 347,
#          'sino': 347,
#          'medica': 347,
#          'insignis': 346,
#          'fortuna': 346,
#          'gigno': 346,
#          'tollo': 344,
#          'membrum': 344,
#          'insero': 343,
#          'diuido': 343,
#          'accido': 343,
#          'morior': 342,
#          'umbra': 342,
#          'sermo': 342,
#          'cura': 341,
#          'saturnus': 341,
#          'zodiacus': 341,
#          'uulnus': 340,
#          'ueritas': 339,
#          'peruenio': 339,
#          'nomino': 338,
#          'produco': 337,
#          'praeditus': 337,
#          'co': 336,
#          'anterus': 334,
#          'hipp': 334,
#          'opticus': 333,
#          'macula': 332,
#          'roma': 331,
#          'interim': 331,
#          'orientalis': 331,
#          'octauus': 330,
#          'acetum': 329,
#          'bibliotheca': 328,
#          'structura': 328,
#          'bene': 327,
#          'crus': 327,
#          'aequatio': 327,
#          'aliter': 326,
#          'ortus': 326,
#          'cubitus': 326,
#          'compono': 325,
#          'excito': 324,
#          'facile': 324,
#          'animalis': 324,
#          'similitudo': 323,
#          'clarus': 322,
#          'cursus': 322,
#          'ibi': 322,
#          'nauis': 322,
#          'vnicus': 322,
#          'quandoquidem': 322,
#          'ein': 322,
#          'coctio': 322,
#          'peculiaris': 321,
#          'diligenter': 321,
#          'copia': 320,
#          'mensura': 320,
#          'praedico': 319,
#          'metallum': 318,
#          'deprehendo': 318,
#          'ex': 318,
#          'uiuo': 317,
#          'usque': 317,
#          'cogo': 317,
#          'inquiro': 317,
#          'pituita': 317,
#          'hippocratis': 317,
#          'illustro': 316,
#          'superus': 316,
#          'hactenus': 315,
#          'comparo': 315,
#          'comprehendo': 315,
#          'nerui': 315,
#          'costa': 315,
#          'admitto': 314,
#          'nonus': 314,
#          'cerno': 312,
#          'ui': 312,
#          'nondum': 312,
#          'alo': 312,
#          'eccentricus': 312,
#          'judicium': 311,
#          'probo': 311,
#          'de': 311,
#          'vsu': 311,
#          'anatomicus': 311,
#          'nego': 310,
#          'uentus': 310,
#          'mobilis': 310,
#          'sicco': 310,
#          'requiro': 310,
#          'hor': 310,
#          'contraho': 310,
#          'quippe': 310,
#          'uicinus': 309,
#          'quę': 308,
#          'urina': 307,
#          'status': 307,
#          'hepar': 306,
#          'pungo': 305,
#          'plerusque': 305,
#          'genitura': 305,
#          'cresco': 304,
#          'publicus': 304,
#          'antiquus': 304,
#          'physicus': 304,
#          'complementum': 304,
#          'basis': 304,
#          'inflammatio': 304,
#          'deduco': 303,
#          'dirigo': 303,
#          'cus': 302,
#          'qvos': 301,
#          'purus': 301,
#          'ala': 301,
#          'eccentricitas': 301,
#          'audio': 300,
#          'absum': 300,
#          'spatium': 300,
#          'utra': 300,
#          'aër': 299,
#          'succum': 299,
#          'duntaxat': 299,
#          'respectus': 299,
#          'procedo': 299,
#          'verùm': 298,
#          'difficultas': 298,
#          'aestas': 298,
#          'aperio': 297,
#          'med': 297,
#          'testimonium': 297,
#          'maximus': 296,
#          'eclipsis': 296,
#          'refrigero': 296,
#          'agnosco': 295,
#          'lector': 293,
#          'concipio': 293,
#          'nonnihil': 293,
#          'assumo': 292,
#          'peregrinus': 292,
#          'sphaera': 292,
#          'experientia': 291,
#          'quaestio': 291,
#          'lis': 290,
#          'marinus': 290,
#          'desino': 289,
#          'diuerto': 289,
#          'defectus': 289,
#          'oblongus': 289,
#          'intestinus': 289,
#          'ferreus': 288,
#          'leuis': 287,
#          'consilium': 287,
#          'incola': 287,
#          'uarietas': 287,
#          'radia': 286,
#          'suscipio': 286,
#          'brahe': 286,
#          'utilis': 285,
#          'tabella': 285,
#          'fere': 285,
#          'demum': 284,
#          'minus': 284,
#          'frater': 283,
#          'origo': 283,
#          'sursum': 283,
#          'sufficio': 282,
#          'passio': 282,
#          'meatus': 282,
#          'calendar': 281,
#          'interuallum': 281,
#          'confirmo': 281,
#          'eclipticae': 281,
#          'constitutio': 281,
#          'morb': 281,
#          'temperamentum': 281,
#          'bini': 280,
#          'generalis': 280,
#          'orio': 280,
#          'georg': 280,
#          'concedo': 279,
#          'ceruix': 278,
#          'prouincia': 278,
#          'uitium': 277,
#          'ro': 277,
#          'insuper': 277,
#          'perpetuus': 276,
#          'fons': 276,
#          'ingens': 276,
#          'nequeo': 276,
#          'singularis': 275,
#          'maleficus': 275,
#          'dissimilis': 274,
#          'multo': 274,
#          'circiter': 274,
#          'prope': 273,
#          'angustus': 273,
#          'spinalis': 273,
#          'iterum': 272,
#          'ambitus': 272,
#          'uersus': 271,
#          'cedo': 271,
#          'dimidius': 271,
#          'praeparo': 271,
#          'densus': 270,
#          'frigus': 269,
#          'obscurus': 269,
#          'quadrans': 269,
#          'ter': 268,
#          'galli': 268,
#          'nigrus': 268,
#          'locum': 268,
#          'construo': 268,
#          'pertineo': 268,
#          'uesica': 268,
#          'silesia': 268,
#          'auis': 267,
#          'falsus': 267,
#          'ignoro': 267,
#          'martius': 267,
#          'dumtaxat': 267,
#          'casus': 266,
#          'idem': 266,
#          'pulsus': 266,
#          'nempe': 265,
#          'recens': 265,
#          'quodammodo': 265,
#          'siccitas': 265,
#          'schenck': 265,
#          'gratus': 264,
#          'seruo': 264,
#          'istic': 264,
#          'lucidus': 263,
#          'scrupulus': 263,
#          'quarta': 263,
#          'placeo': 262,
#          'us': 262,
#          'declaro': 262,
#          'longe': 260,
#          'epistola': 260,
#          'occidentalis': 260,
#          'transfero': 259,
#          'editio': 259,
#          'ephemerides': 259,
#          'tab': 259,
#          'uicis': 258,
#          'mel': 258,
#          'astronomia': 258,
#          'tùm': 258,
#          'augustus': 257,
#          'bibo': 257,
#          'alienus': 257,
#          'flos': 256,
#          'firmus': 256,
#          'triplex': 256,
#          'gemma': 256,
#          'antecedo': 256,
#          'utrius': 256,
#          'morsus': 256,
#          'ecliptica': 255,
#          'hippoc': 255,
#          'mox': 254,
#          'mutuus': 254,
#          'misceo': 254,
#          'penna': 254,
#          'respicio': 254,
#          'tychonis': 254,
#          'decoctum': 254,
#          'separo': 253,
#          'argentum': 253,
#          'quòad': 253,
#          'index': 253,
#          'eo': 252,
#          'alibi': 252,
#          'intus': 252,
#          'consisto': 252,
#          'graf': 252,
#          'ne': 251,
#          'officium': 251,
#          'majus': 251,
#          'fibra': 251,
#          'testor': 251,
#          'deorsum': 251,
#          'mutatio': 251,
#          'pus': 250,
#          'designo': 250,
#          'crassior': 250,
#          'nux': 250,
#          'laus': 249,
#          'felix': 249,
#          'praecipuus': 249,
#          'excedo': 249,
#          'humerus': 249,
#          'inaequalis': 249,
#          'aëre': 249,
#          'uxor': 248,
#          'compositio': 248,
#          'gallia': 247,
#          'aufero': 247,
#          'vertebra': 247,
#          'inprimis': 246,
#          'fundamentum': 246,
#          'medicae': 246,
#          'nutritio': 246,
#          'turcae': 246,
#          'flumen': 245,
#          'io': 245,
#          'sidus': 244,
#          'assero': 244,
#          'prędico': 244,
#          'corrumpo': 243,
#          'istîc': 243,
#          'euado': 242,
#          'eclipticus': 242,
#          'bellum': 241,
#          'mercurius': 241,
#          ...})

# %%
periods = [(1501, 1550),
           (1551, 1600),
           (1601, 1650),
           (1651, 1700)]
periods_vocabs = []
full_vocabs = []
for per in periods:
    ids = metadata_table_long[metadata_table_long["file_year"].between(per[0], per[1])]["id"] # use the metadata table to extract IDs of all works falling into this period
    vocab = get_filtered_counts_by_ids(ids)
    periods_vocabs.append(vocab)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 9
#       7 for per in periods:
#       8     ids = metadata_table_long[metadata_table_long["file_year"].between(per[0], per[1])]["id"] # use the metadata table to extract IDs of all works falling into this period
# ----> 9     vocab = get_filtered_counts_by_ids(ids)
#      10     periods_vocabs.append(vocab)
#
# Cell In[11], line 10, in get_filtered_counts_by_ids(ids)
#       7 # based on the ID, open the file containing POS tags of the sentences and load its content as a list of lists
#       8 # (this object should have the same structure as the previous one, what allows us to do a sort of filtering based on selected POS tags
#       9 with open("../data/large_data/sents_pos/{}.txt".format(str(id)), "r") as f:
# ---> 10     sents_pos = [sent.strip().split() for sent in f.readlines()]
#      11 sents_lemmata_filtered = [] # initiate a new empty list for sentence lemmata filtered by POS tags
#      12 for n in range(len(sents_lemmata)):
#
# Cell In[11], line 10, in <listcomp>(.0)
#       7 # based on the ID, open the file containing POS tags of the sentences and load its content as a list of lists
#       8 # (this object should have the same structure as the previous one, what allows us to do a sort of filtering based on selected POS tags
#       9 with open("../data/large_data/sents_pos/{}.txt".format(str(id)), "r") as f:
# ---> 10     sents_pos = [sent.strip().split() for sent in f.readlines()]
#      11 sents_lemmata_filtered = [] # initiate a new empty list for sentence lemmata filtered by POS tags
#      12 for n in range(len(sents_lemmata)):
#
# KeyboardInterrupt:

# %%
topn = 2000
vocabs_topn_lists =[list(vocab.keys())[:topn] for vocab in periods_vocabs]

# %%
vocab_union = set.union(*[set(vocab) for vocab in vocabs_topn_lists])
len(vocab_union)

# %%
# add there also the words appearing both in lasla and operamaiora
vocab_union = set.union(*[set(vocab) for vocab in vocabs_topn_lists] + [set(vocab_overlap)])
len(vocab_union)

# %%
vocab_union_df = pd.DataFrame(vocab_union, columns = ["word"])
vocab_union_df

# %%
# add the counts of these words from the vocabularies
def find_in_vocab(word, vocab):
    try:
        return vocab[word]
    except:
        return 0
for vocab, per in zip(periods_vocabs, [str(tup[0])+"-"+str(tup[1]) for tup in periods]):
    vocab_union_df[per] = vocab_union_df["word"].apply(lambda x: find_in_vocab(x, vocab))

# %%
# calculate the mean value for sorting
vocab_union_df["mean"] = vocab_union_df[vocab_union_df.columns[1:]].mean(axis=1)
vocab_union_df.sort_values("mean", ascending=False, inplace=True)
vocab_union_df.head(20)

# %%
vocab_union_df.tail(10)

# %%
# Filter only for words appearing at least 5 times in each of the subcorpora
filtered_vocab_df = vocab_union_df[
    (vocab_union_df['1501-1550'] >= 5) &
    (vocab_union_df['1551-1600'] >= 5) &
    (vocab_union_df['1601-1650'] >= 5) &
    (vocab_union_df['1651-1700'] >= 5)
    ]

# %%
len(filtered_vocab_df)

# %%
filtered_vocab_df.head(10)

# %%
filtered_vocab_df.tail(10)

# %%
filtered_vocab_df["in_lila_embeddings"] = filtered_vocab_df["word"].apply(lambda x: x in vocab_overlap)

# %%
filtered_vocab_df["in_lasla"] = filtered_vocab_df["word"].apply(lambda x: x in lasla_vocab)
filtered_vocab_df["in_operamaiora"] = filtered_vocab_df["word"].apply(lambda x: x in operamaiora_vocab)

# %%
filtered_vocab_df.head(100)

# %%
filtered_vocab_df["in_lasla"].sum()

# %%
filtered_vocab_df["in_operamaiora"].sum()

# %%
filtered_vocab_df["in_lila_embeddings"].sum()

# %% [markdown]
# # Add simple english translation

# %%
# simple latin API:
# https://www.latin-is-simple.com/api/

# %%
target = "equus"
base_url = "https://www.latin-is-simple.com/api/vocabulary/search/?query={}&forms_only=true"
resp_json = requests.get(base_url.format(target)).json()
resp_json

# %%
resp_json[0]["translations_unstructured"]["en"]

# %%
def simple_translation(target):
    try:
        base_url = "https://www.latin-is-simple.com/api/vocabulary/search/?query={}&forms_only=true"
        resp_json = requests.get(base_url.format(target)).json()
        transl = resp_json[0]["translations_unstructured"]["en"]
        if transl == "still in translation":
            transl = ""
        return transl
    except:
        return ""

# %%
# %%time
filtered_vocab_df["transl"] = filtered_vocab_df["word"].apply(simple_translation)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File <timed eval>:1
#
# NameError: name 'simple_translation' is not defined

# %%
filtered_vocab_df.to_json("../data/filtered_vocab_df.json")
